# %%
import torch

# %%
checkpoint = torch.load("../models/growth_model_best_v1.pth")

# %%
checkpoint.keys()
# Out:
# dict_keys(['epoch', 'model_state_dict', 'optimizer_state_dict', 'loss'])

# %%
for key, value in checkpoint['model_state_dict'].items():
    print(f"Layer: {key} | Shape: {value.shape}")
# Out:
# Layer: porcini_net.0.weight | Shape: torch.Size([32, 13])
# Layer: porcini_net.0.bias | Shape: torch.Size([32])
# Layer: porcini_net.2.weight | Shape: torch.Size([1, 32])
# Layer: porcini_net.2.bias | Shape: torch.Size([1])
# Layer: chanterelle_net.0.weight | Shape: torch.Size([32, 13])
# Layer: chanterelle_net.0.bias | Shape: torch.Size([32])
# Layer: chanterelle_net.2.weight | Shape: torch.Size([1, 32])
# Layer: chanterelle_net.2.bias | Shape: torch.Size([1])
