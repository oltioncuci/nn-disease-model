# %% [markdown]
# # Model Evaluation EDA
# **Source Report:** `reports/nn_1_final_acc_97.8_2026-03-12_09-50-50_detailed.csv`
# **Generated on:** 2026-03-12 09-51

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_theme(style='whitegrid')

# %%
df = pd.read_csv('../reports/nn_1_final_acc_97.8_2026-03-12_09-50-50_detailed.csv')
df.head()

# %%
print('--- Accuracy Overview ---')
print(df['Correct'].value_counts(normalize=True))

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Actual_Disease', hue='Correct')
plt.title('Correct vs Incorrect Predictions per Class')
plt.xticks(rotation=45)
plt.show()
